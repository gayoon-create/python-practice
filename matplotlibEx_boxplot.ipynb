# %% [markdown]
# boxplot : 주식 차트를 그릴 때 사용되는 차트
# 주어진 데이터에서 최대값, 최소값, 4/1, 3/4, 중간값을 추출하여 차트를 그려준다.

# %%
import matplotlib.pyplot as plt
import random
import numpy as np

result = []

for i in range(50) :
    result.append(random.randint(1, 100))

print(sorted(result))

npArr = np.array(result)
print("최대값 : %d, 최소값 : %d" % (npArr.max(), npArr.min()))
print("1/4 : %d, 3/4 : %d, 중간값 : %d" % (np.percentile(npArr, 25), np.percentile(npArr, 75), np.median(npArr)))

plt.boxplot(result)
plt.show()
# Out:
# [1, 2, 3, 4, 5, 6, 6, 9, 10, 12, 13, 14, 16, 17, 24, 27, 27, 31, 33, 37, 38, 38, 41, 41, 46, 48, 49, 55, 56, 57, 60, 60, 61, 61, 61, 63, 64, 66, 69, 69, 72, 73, 73, 77, 80, 82, 85, 86, 96, 100]
# 최대값 : 100, 최소값 : 1
# 1/4 : 16, 3/4 : 65, 중간값 : 47
